# %% [markdown]
# # Прогресс и путевые заметки

# %% [markdown]
# ## 1.09.17
# ### Готово:
# Просмотрел первый урок, добился работоспособности кода из урока на сервере. Нейросеть на сервере успешно распознает класс картинки (что изображено) из 1000 возможных. В качестве модели используется уже обученная Vgg16.
#
# Исправил ошибки, связанные с конфликтами версий библиотек на сервере.
# ### Планы на завтра:
# Дообучить модель имеющимися в проекте картинками, научить решать задачу кошка/собака.
# Создать собственную модель для решения той же задачи.

# %% [markdown]
# ## 3.09.17
# ###  Готово:
# Имеющаяся модель дообучена до возможности распознавать собаку или кошку (вместо 1000 паттернов), пройдены испытания модели на больших даннных. Выяснил, что GTX 780 вполне справляется с поставленнными задачами, железа хватит на весь период обучения. Разобран способ создания простейшей нейросети из 10 слоев для решения задачи собака/кошка, естественно с меньшей точностью чем Vgg16, но тоже прилично.
# Просмотрел второй урок, вник в основы машинного обучения, разобрал в теории линейные модели, алгоритмы определения точности линейной модели, способы ее обучения (с оптимизациями). Разобрал принцип работы нейросети в целом, изучил возможности и назначение каждого слоя.
# Узнал о двух способах решения задачи 1000 паттернов -> кошка или собака. Первый предполагает создание линейной модели с 1000 входами и двумя выходами, второй - переобучение верхнего слоя Vgg16.
# ### Планы
# Изучить все вышеперечисленное на практике.
